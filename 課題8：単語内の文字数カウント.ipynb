# %%
english=[]
code1=dict.fromkeys(list("abcdefghijklmnopqrstuvwxyz"), 0)
while True:
    word=input("英単語を入力してください：")
    if word=="":
        break
    english.append(word)
english.sort()   
print(f"入力した英単語:{english}")    
    
for word1 in english:
    for letter in word1:
        if letter in code1.keys():
            code1[letter]+=1

for key,value in code1.items():
    if value>0:
        print(f"{key}が{value}個ありました")
# Out:
# 入力した英単語:['cat', 'dog', 'rabbit']
# aが2個ありました
# bが2個ありました
# cが1個ありました
# dが1個ありました
# gが1個ありました
# iが1個ありました
# oが1個ありました
# rが1個ありました
# tが2個ありました

# %%
eng=[]
code1=dict.fromkeys(list("abcdefghijklmnopqrstuvwxyz"), 0)
while True:
    word=input("英単語を入力してください：")
    if word=="":
        break
    eng.append(word)
eng=eng.sort()
print(f"入力した英単語:{eng}")
# Out:
# 入力した英単語:None

# %%
english=[]
code1=dict.fromkeys(list("abcdefghijklmnopqrstuvwxyz"), 0)
while True:
    word=input("英単語を入力してください：")
    if word=="":
        break
    english.append(word)
    
for word1 in english:
    for letter in word1:
        if letter in code1.keys():
            code1[letter]+=1
print(f"入力した英単語:{english.sort()}")
# Out:
# 入力した英単語:None

# %%
english=[]
code1=dict.fromkeys(list("abcdefghijklmnopqrstuvwxyz"), 0)
while True:
    word=input("英単語を入力してください：")
    if word=="":
        break
    english.append(word)
print(english)
# Out:
# ['cat', 'dog']

# %%
char1=word.list()
char1+=char1


char1=word.list()
    char1+=char1

# %%
while True:
    word=input("英単語を入力してください：")
    if word=="cat":
        break
print(word)
# Out:
# cat

# %%
english=[]
code1=dict.fromkeys(list("abcdefghijklmnopqrstuvwxyz"), 0)
while True:
    word=input("英単語を入力してください：")
    if word==_:
        break
    english.append(word)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 4
#       2 code1=dict.fromkeys(list("abcdefghijklmnopqrstuvwxyz"), 0)
#       3 while True:
# ----> 4     word=input("英単語を入力してください：")
#       5     english.append(word)
#       6     if word==_:
#
# File ~/Downloads/pythondev/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:1396, in Kernel.raw_input(self, prompt)
#    1394     msg = "raw_input was called, but this frontend does not support input requests."
#    1395     raise StdinNotImplementedError(msg)
# -> 1396 return self._input_request(
#    1397     str(prompt),
#    1398     self._get_shell_context_var(self._shell_parent_ident),
#    1399     self.get_parent("shell"),
#    1400     password=False,
#    1401 )
#
# File ~/Downloads/pythondev/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:1441, in Kernel._input_request(self, prompt, ident, parent, password)
#    1438 except KeyboardInterrupt:
#    1439     # re-raise KeyboardInterrupt, to truncate traceback
#    1440     msg = "Interrupted by user"
# -> 1441     raise KeyboardInterrupt(msg) from None
#    1442 except Exception:
#    1443     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
