# %%
s = "abcdefghijklmnopqrstuvwxyz"
s[:-10]
# Out:
# 'abcdefghijklmnop'

# %%
english=[]
code1=dict.fromkeys(list("abcdefghijklmnopqrstuvwxyz"), 0)
while True:
    word=input("英単語を入力してください：")
    english.append(word)
    if word==_:
        break
for word1 in english:
    for letter in word1

print(f"入力した英単語:{english.sort()}")
print(f"{key}が{value}個ありました")

# %%
num4 = [i for i in range(11) if i != 5]
num4
# Out:
# [0, 1, 2, 3, 4, 6, 7, 8, 9, 10]

# %%
num5 = ["low" if i < 3 else "mid" if i < 8 else "hi" for i in range(11) if i % 2 == 0]
num5
# Out:
# ['low', 'low', 'mid', 'mid', 'hi', 'hi']

# %%
import health

# %%
print(type(health))
# Out:
# <class 'module'>

# %%
print(health)
# Out:
# <module 'health' from '/Users/y-shibata/Downloads/pythondev/health.py'>

# %%
height = float(input("身長(m)を入力してください："))
weight = float(input("体重(kg)を入力してください："))

my_bmi = health.bmi(height, weight)
my_standard_weight = health.standard_weight(height)

print(f"BMI値：{my_bmi:.1f}")
print(f"標準体重：{my_standard_weight:.1f}kg")
# Out:
# BMI値：20.8
# 標準体重：63.6kg
