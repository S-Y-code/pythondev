# %%
price=int(input("税抜き価格を入力してください："))
tax_price=round(price*1.1)
if tax_price>=2000:
    print("送料は無料です")
else:
    print("送料として350円かかります")
    tax_price+=350
    print(f"送料込みの価格は{tax_price}円です。")
# Out:
# 送料として350円かかります
# 送料込みの価格は2330円です。
